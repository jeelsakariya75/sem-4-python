# %%
import pandas as pd
import numpy as np

# %%
df=pd.Series([10,20,30])
print(df)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
print(type(df))
# Out:
# <class 'pandas.core.series.Series'>

# %%
dk=pd.Series((10,20,30))
print(dk)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
dv=pd.Series({'A':10,'B':20,'C':30})
print(dv)
# Out:
# A    10
# B    20
# C    30
# dtype: int64

# %%
df=pd.Series(np.array([10,20,30]))
print(df)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int32

# %%
df=pd.Series(np.array([10,20,30]),index=['p','q','r'])
print(df)
# Out:
# p    10
# q    20
# r    30
# dtype: int32

# %%
df=pd.DataFrame([['B9','B8','B7'],['10','9','8'],['7000','3000','5000']])
print(df)
# Out:
#       0     1     2
# 0    B9    B8    B7
# 1    10     9     8
# 2  7000  3000  5000

# %%
df=pd.DataFrame([['B9','B8','B7'],['10','9','8'],['7000','3000','5000']],index=['a','b','c'],columns=['p','q','r'])
print(df)
# Out:
#       p     q     r
# a    B9    B8    B7
# b    10     9     8
# c  7000  3000  5000

# %%
df=pd.DataFrame({'A':[7,8,9],'B':[11,12,13],'C':['X','Y','Z']},index=['p','q','r'])
print(df)
# Out:
#    A   B  C
# p  7  11  X
# q  8  12  Y
# r  9  13  Z

# %%
df=pd.DataFrame([{'name':'Vishal','m':10},{'name':'yug','m':9}])
print(df)
# Out:
#      name   m
# 0  Vishal  10
# 1     yug   9

# %%
df=pd.read_csv('train.csv')
print(df)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.values
# Out:
# array([[1, 0, 3, ..., 7.25, nan, 'S'],
#        [2, 1, 1, ..., 71.2833, 'C85', 'C'],
#        [3, 1, 3, ..., 7.925, nan, 'S'],
#        ...,
#        [889, 0, 3, ..., 23.45, nan, 'S'],
#        [890, 1, 1, ..., 30.0, 'C148', 'C'],
#        [891, 0, 3, ..., 7.75, nan, 'Q']], dtype=object)

# %%
df.shape
# Out:
# (891, 12)

# %%
df.size #number of row maltipay by number of column
# Out:
# 10692

# %%
df=pd.DataFrame([[10,20,30],[40,50,60],[70,80,90]],index=['P','Q','R'],columns=['A','B','C'])
print(df)
# Out:
#     A   B   C
# P  10  20  30
# Q  40  50  60
# R  70  80  90

# %%
df['A']
# Out:
# P    10
# Q    40
# R    70
# Name: A, dtype: int64

# %%
df['C']
# Out:
# P    30
# Q    60
# R    90
# Name: C, dtype: int64

# %%
df[['A','B']]
# Out:
#     A   B
# P  10  20
# Q  40  50
# R  70  80

# %%
df.loc['P']
# Out:
# A    10
# B    20
# C    30
# Name: P, dtype: int64

# %%
df.loc['P','B']
# Out:
# 20

# %%
df.loc[:,'C']
# Out:
# P    30
# Q    60
# R    90
# Name: C, dtype: int64

# %%
df.loc['P':'Q','A':'B']
# Out:
#     A   B
# P  10  20
# Q  40  50

# %%
df.loc[['P','Q'],['B','C']]
# Out:
#     B   C
# P  20  30
# Q  50  60

# %%
df.loc[['P','R'],['A','C']]
# Out:
#     A   C
# P  10  30
# R  70  90

# %%
df.loc['Q','B']=70

# %%
print(df)
# Out:
#     A   B   C
# P  10  20  30
# Q  40  70  60
# R  70  80  90

# %%
df.loc['X']=[70,90,100]
print(df)
# Out:
#     A   B    C
# P  10  20   30
# Q  40  70   60
# R  70  80   90
# X  70  90  100

# %%
df['D']=10

# %%
print(df)
# Out:
#     A   B    C   D
# P  10  20   30  10
# Q  40  70   60  10
# R  70  80   90  10
# X  70  90  100  10

# %%
df=pd.DataFrame([[10,20,30],[40,50,60],[70,80,90]])
print(df)
# Out:
#     0   1   2
# 0  10  20  30
# 1  40  50  60
# 2  70  80  90

# %%
df.iloc[1,1]
# Out:
# 50

# %%
df.iloc[1]
# Out:
# 0    40
# 1    50
# 2    60
# Name: 1, dtype: int64

# %%
df.iloc[:,1]
# Out:
# 0    20
# 1    50
# 2    80
# Name: 1, dtype: int64

# %%
df.iloc[0:2,0:2]
# Out:
#     0   1
# 0  10  20
# 1  40  50

# %%
df.iloc[:,1:3]
# Out:
#     1   2
# 0  20  30
# 1  50  60
# 2  80  90

# %%
df=pd.read_csv('train.csv')
print(df)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df=df.set_index('Name')

# %%
print(df)
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# ...                                                         ...       ...
# Montvila, Rev. Juozas                                       887         0
# Graham, Miss. Margaret Edith                                888         1
# Johnston, Miss. Catherine Helen "Carrie"                    889         0
# Behr, Mr. Karl Howell                                       890         1
# Dooley, Mr. Patrick                                         891         0
#
# ...

# %%
df=df.reset_index()

# %%
print(df)
# Out:
#                                                   Name  PassengerId  Survived  \
# 0                              Braund, Mr. Owen Harris            1         0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...            2         1
# 2                               Heikkinen, Miss. Laina            3         1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)            4         1
# 4                             Allen, Mr. William Henry            5         0
# ..                                                 ...          ...       ...
# 886                              Montvila, Rev. Juozas          887         0
# 887                       Graham, Miss. Margaret Edith          888         1
# 888           Johnston, Miss. Catherine Helen "Carrie"          889         0
# 889                              Behr, Mr. Karl Howell          890         1
# 890                                Dooley, Mr. Patrick          891         0
#
# ...

# %%
df.head(3)
# Out:
#                                                 Name  PassengerId  Survived  \
# 0                            Braund, Mr. Owen Harris            1         0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...            2         1
# 2                             Heikkinen, Miss. Laina            3         1
#
#    Pclass     Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# 0       3    male  22.0      1      0         A/5 21171   7.2500   NaN
# 1       1  female  38.0      1      0          PC 17599  71.2833   C85
# 2       3  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN
#
#   Embarked
# 0        S
# 1        C
# 2        S

# %%
df.tail(5)
# Out:
#                                          Name  PassengerId  Survived  Pclass  \
# 886                     Montvila, Rev. Juozas          887         0       2
# 887              Graham, Miss. Margaret Edith          888         1       1
# 888  Johnston, Miss. Catherine Helen "Carrie"          889         0       3
# 889                     Behr, Mr. Karl Howell          890         1       1
# 890                       Dooley, Mr. Patrick          891         0       3
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.sample(7)
# Out:
#                                                   Name  PassengerId  Survived  \
# 319  Spedden, Mrs. Frederic Oakley (Margaretta Corn...          320         1
# 867               Roebling, Mr. Washington Augustus II          868         0
# 508                           Olsen, Mr. Henry Margido          509         0
# 293                                Haas, Miss. Aloisia          294         0
# 819                       Skoog, Master. Karl Thorsten          820         0
# 810                             Alexander, Mr. William          811         0
# 757                           Bailey, Mr. Percy Andrew          758         0
#
#      Pclass     Sex   Age  SibSp  Parch    Ticket      Fare Cabin Embarked
# 319       1  female  40.0      1      1     16966  134.5000   E34        C
# 867       1    male  31.0      0      0  PC 17590   50.4958   A24        S
# 508       3    male  28.0      0      0    C 4001   22.5250   NaN        S
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         891 non-null    object
#  1   PassengerId  891 non-null    int64
#  2   Survived     891 non-null    int64
#  3   Pclass       891 non-null    int64
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.describe(include='all')
# Out:
#                                 Name  PassengerId    Survived      Pclass  \
# count                            891   891.000000  891.000000  891.000000
# unique                           891          NaN         NaN         NaN
# top     Harknett, Miss. Alice Phoebe          NaN         NaN         NaN
# freq                               1          NaN         NaN         NaN
# mean                             NaN   446.000000    0.383838    2.308642
# std                              NaN   257.353842    0.486592    0.836071
# min                              NaN     1.000000    0.000000    1.000000
# 25%                              NaN   223.500000    0.000000    2.000000
# 50%                              NaN   446.000000    0.000000    3.000000
# 75%                              NaN   668.500000    1.000000    3.000000
# max                              NaN   891.000000    1.000000    3.000000
#
#          Sex         Age       SibSp       Parch Ticket        Fare  \
# ...

# %%
df.describe(include='object')
# Out:
#                                 Name   Sex Ticket        Cabin Embarked
# count                            891   891    891          204      889
# unique                           891     2    681          147        3
# top     Harknett, Miss. Alice Phoebe  male   1601  C23 C25 C27        S
# freq                               1   577      7            4      644

# %%
df['Sex']=='female'
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 886    False
# 887     True
# 888     True
# 889    False
# 890    False
# Name: Sex, Length: 891, dtype: bool

# %%
df[df['Sex']=='female']
# Out:
#                                                   Name  PassengerId  Survived  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...            2         1
# 2                               Heikkinen, Miss. Laina            3         1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)            4         1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)            9         1
# 9                  Nasser, Mrs. Nicholas (Adele Achem)           10         1
# ..                                                 ...          ...       ...
# 880       Shelley, Mrs. William (Imanita Parrish Hall)          881         1
# 882                       Dahlberg, Miss. Gerda Ulrika          883         0
# 885               Rice, Mrs. William (Margaret Norton)          886         0
# 887                       Graham, Miss. Margaret Edith          888         1
# 888           Johnston, Miss. Catherine Helen "Carrie"          889         0
#
# ...

# %%
df[(df['Sex']=='female')&(df['Survived']==1)]
# Out:
#                                                   Name  PassengerId  Survived  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...            2         1
# 2                               Heikkinen, Miss. Laina            3         1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)            4         1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)            9         1
# 9                  Nasser, Mrs. Nicholas (Adele Achem)           10         1
# ..                                                 ...          ...       ...
# 874              Abelson, Mrs. Samuel (Hannah Wizosky)          875         1
# 875                   Najib, Miss. Adele Kiamie "Jane"          876         1
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)          880         1
# 880       Shelley, Mrs. William (Imanita Parrish Hall)          881         1
# 887                       Graham, Miss. Margaret Edith          888         1
#
# ...

# %%
df[(df['Sex']=='male')&(df['Survived']==1)]
# Out:
#                                 Name  PassengerId  Survived  Pclass   Sex  \
# 17      Williams, Mr. Charles Eugene           18         1       2  male
# 21             Beesley, Mr. Lawrence           22         1       2  male
# 23      Sloper, Mr. William Thompson           24         1       1  male
# 36                  Mamee, Mr. Hanna           37         1       3  male
# 55                 Woolner, Mr. Hugh           56         1       1  male
# ..                               ...          ...       ...     ...   ...
# 838                  Chip, Mr. Chang          839         1       3  male
# 839             Marechal, Mr. Pierre          840         1       1  male
# 857           Daly, Mr. Peter Denis           858         1       1  male
# 869  Johnson, Master. Harold Theodor          870         1       3  male
# 889            Behr, Mr. Karl Howell          890         1       1  male
#
#       Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# ...

# %%
df[(df['Age']<12)&(df['Survived']==1)].shape[0]
# Out:
# 39

# %%
df.describe(percentiles=[0.2,0.4])
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 20%     179.000000    0.000000    1.000000   19.000000    0.000000
# 40%     357.000000    0.000000    2.000000   25.000000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 20%      0.000000    7.854200
# 40%      0.000000   10.500000
# 50%      0.000000   14.454200
# max      6.000000  512.329200
